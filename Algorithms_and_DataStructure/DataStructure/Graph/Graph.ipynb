# %% [markdown]
# # I. Graph

# %% [markdown]
# ## Minimum Spanning Tree

# %% [markdown]
# ### I. Prim

# %% [markdown]
# ### II. Kruskal Algorithm

# %%
def kruskal(graph):
    
    # weights on edges sorting in magnitude

# %% [markdown]
# # Topological Sorting

# %% [markdown]
# # Shortest Path Probs

# %% [markdown]
# ## Dijkstra

# %% [markdown]
# ## Bellman-Ford Algorithm

# %% [markdown]
# ## FloydWarshall Algorithm

# %% [markdown]
# ## shortest path in Directed Acyclic Graph

# %% [markdown]
# ## To get strongly connected components

# %% [markdown]
# # II. String Matching

# %% [markdown]
# ## Rabin-Karp Algorithm

# %% [markdown]
# ## KMP- Algorithm

# %% [markdown]
# ## BoyerMoore Algorithm

# %% [markdown]
# # III. Searching Trees

# %% [markdown]
# ## IV. NP-completeness
