# %% [markdown]
# # Logistic Regression by Tensorflow

# %% [markdown]
# ## Cross Entropy (CE)
# H(p,q) = - SIGMA(x) p(x)*log q(x)
# p: target, q: estimate

# %% [markdown]
# ## CE in Neural Net
# CE = - SIGMA(D) SIGMA(K) P(target = K) log P(estimate = K)
#
# D : # of batch
# K : # of class
# P : by softmax

# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets('data/', one_hot=True)
x_train = mnist.train.images
y_train = mnist.train.labels
x_test = mnist.test.images
y_test = mnist.test.labels
x_valid = mnist.validation.images
y_valid = mnist.validation.labels
# Out:
# Extracting data/train-images-idx3-ubyte.gz
# Extracting data/train-labels-idx1-ubyte.gz
# Extracting data/t10k-images-idx3-ubyte.gz
# Extracting data/t10k-labels-idx1-ubyte.gz

# %%
X = tf.placeholder(tf.float32, [None,28*28])
Y = tf.placeholder(tf.float32, [None,10])
W = tf.Variable(tf.random_normal([784,10], stddev=0.1),dtype=tf.float32)
b = tf.Variable(tf.zeros([10]))

layer1 = tf.layers.dense(X, 10, activation = None, kernel_initializer = tf.initializers.truncated_normal)

actv1 = tf.nn.softmax(tf.matmul(X,W)+b)

actv2 = tf.nn.softmax(layer1)

def cost_fcn(actv):
    return tf.reduce_mean(-tf.reduce_sum(Y*tf.log(actv), reduction_indices = 1))

cost1 = cost_fcn(actv1)
cost2 = cost_fcn(actv2)

learning_rate = 0.01
optm1 = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost1)
optm2 = tf.train.GradientDescentOptimizer(learning_rate).minimize(cost2)

# %%
pred1 = tf.equal(tf.argmax(actv1,1),tf.argmax(Y,1))
pred2 = tf.equal(tf.argmax(actv2,1),tf.argmax(Y,1))

accr1 = tf.reduce_mean(tf.cast(pred1,tf.float32))
accr2 = tf.reduce_mean(tf.cast(pred2,tf.float32))

# %%
training_epochs = 50
batch_size = 100
init = tf.global_variables_initializer()

# %%
batch_size

with tf.Session() as sess:
    sess.run(init)
    train_accr1=[]
    train_accr2=[]
    test_accr1=[]
    test_accr2=[]
    
    for epoch in range(training_epochs):
        avg_cost1 = 0
        avg_cost2 = 0
        num_batch = x_train.shape[0]//batch_size
        for i in range(num_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(optm1,feed_dict={X:batch_xs, Y:batch_ys})
            sess.run(optm2,feed_dict={X:batch_xs, Y:batch_ys})
            
            avg_cost1 += sess.run(cost1,feed_dict={X:batch_xs, Y:batch_ys})/num_batch
            avg_cost2 += sess.run(cost2,feed_dict={X:batch_xs, Y:batch_ys})/num_batch
            
        if epoch % 5:
            train_ac1 = sess.run(accr1, feed_dict={X:batch_xs, Y:batch_ys})
            train_ac2 = sess.run(accr2, feed_dict={X:batch_xs, Y:batch_ys})
            test_ac1 = sess.run(accr1, feed_dict={X:x_valid, Y:y_valid})
            test_ac2 = sess.run(accr2, feed_dict={X:x_valid, Y:y_valid})
            
            print(f"Epoch: #{epoch}")
            print("#1")
            print(f"train accuracy: {train_ac1}\t test accuracy: {test_ac1}")
            print("#2")
            print(f"train accuracy: {train_ac2}\t test accuracy: {test_ac2}")
            train_accr1.append(train_ac1)
            train_accr2.append(train_ac2)
            test_accr1.append(test_ac1)
            test_accr2.append(test_ac2)
# Out:
# Epoch: #1
# #1
# train accuracy: 0.9200000166893005	 test accuracy: 0.8478000164031982
# #2
# train accuracy: 0.550000011920929	 test accuracy: 0.4903999865055084
# Epoch: #2
# #1
# train accuracy: 0.9100000262260437	 test accuracy: 0.8651999831199646
# #2
# train accuracy: 0.5899999737739563	 test accuracy: 0.5845999717712402
# Epoch: #3
# #1
# train accuracy: 0.8899999856948853	 test accuracy: 0.8759999871253967
# #2
# train accuracy: 0.6000000238418579	 test accuracy: 0.645799994468689
# Epoch: #4
# #1
# train accuracy: 0.8899999856948853	 test accuracy: 0.8849999904632568
# #2
# train accuracy: 0.6299999952316284	 test accuracy: 0.6832000017166138
# Epoch: #6
# #1
# train accuracy: 0.8500000238418579	 test accuracy: 0.8925999999046326
# #2
# train accuracy: 0.7099999785423279	 test accuracy: 0.7333999872207642
# Epoch: #7
# #1
# train accuracy: 0.8899999856948853	 test accuracy: 0.8944000005722046
# #2
# train accuracy: 0.7400000095367432	 test accuracy: 0.7468000054359436
# Epoch: #8
# #1
# train accuracy: 0.8500000238418579	 test accuracy: 0.8980000019073486
# #2
# train accuracy: 0.6800000071525574	 test accuracy: 0.7616000175476074
# Epoch: #9
# #1
# train accuracy: 0.8999999761581421	 test accuracy: 0.8985999822616577
# #2
# train accuracy: 0.7900000214576721	 test accuracy: 0.7716000080108643
# Epoch: #11
# #1
# train accuracy: 0.8799999952316284	 test accuracy: 0.9016000032424927
# #2
# train accuracy: 0.8600000143051147	 test accuracy: 0.7870000004768372
# Epoch: #12
# #1
# train accuracy: 0.949999988079071	 test accuracy: 0.9031999707221985
# #2
# train accuracy: 0.8100000023841858	 test accuracy: 0.7943999767303467
# Epoch: #13
# #1
# train accuracy: 0.9300000071525574	 test accuracy: 0.9035999774932861
# #2
# train accuracy: 0.7900000214576721	 test accuracy: 0.8014000058174133
# Epoch: #14
# #1
# train accuracy: 0.8999999761581421	 test accuracy: 0.9043999910354614
# #2
# train accuracy: 0.8299999833106995	 test accuracy: 0.8076000213623047
# Epoch: #16
# #1
# train accuracy: 0.949999988079071	 test accuracy: 0.9061999917030334
# #2
# train accuracy: 0.8399999737739563	 test accuracy: 0.8176000118255615
# Epoch: #17
# #1
# train accuracy: 0.8700000047683716	 test accuracy: 0.9093999862670898
# #2
# train accuracy: 0.8100000023841858	 test accuracy: 0.821399986743927
# Epoch: #18
# #1
# train accuracy: 0.8899999856948853	 test accuracy: 0.9089999794960022
# #2
# train accuracy: 0.8100000023841858	 test accuracy: 0.8248000144958496
# Epoch: #19
# #1
# train accuracy: 0.8999999761581421	 test accuracy: 0.9093999862670898
# #2
# train accuracy: 0.8399999737739563	 test accuracy: 0.8284000158309937
# Epoch: #21
# #1
# train accuracy: 0.8899999856948853	 test accuracy: 0.9111999869346619
# #2
# train accuracy: 0.800000011920929	 test accuracy: 0.8320000171661377
# Epoch: #22
# #1
# train accuracy: 0.9300000071525574	 test accuracy: 0.9124000072479248
# #2
# train accuracy: 0.8700000047683716	 test accuracy: 0.8352000117301941
# Epoch: #23
# #1
# train accuracy: 0.9100000262260437	 test accuracy: 0.9118000268936157
# #2
# train accuracy: 0.8500000238418579	 test accuracy: 0.8375999927520752
# Epoch: #24
# #1
# train accuracy: 0.8600000143051147	 test accuracy: 0.9124000072479248
# #2
# train accuracy: 0.8299999833106995	 test accuracy: 0.8407999873161316
# Epoch: #26
# #1
# train accuracy: 0.949999988079071	 test accuracy: 0.9133999943733215
# #2
# train accuracy: 0.8899999856948853	 test accuracy: 0.84579998254776
# Epoch: #27
# #1
# train accuracy: 0.9100000262260437	 test accuracy: 0.9129999876022339
# #2
# train accuracy: 0.8899999856948853	 test accuracy: 0.8474000096321106
# Epoch: #28
# #1
# train accuracy: 0.8999999761581421	 test accuracy: 0.9142000079154968
# #2
# train accuracy: 0.8199999928474426	 test accuracy: 0.8489999771118164
# Epoch: #29
# #1
# train accuracy: 0.9300000071525574	 test accuracy: 0.9138000011444092
# #2
# train accuracy: 0.8799999952316284	 test accuracy: 0.8529999852180481
# Epoch: #31
# #1
# train accuracy: 0.8799999952316284	 test accuracy: 0.9150000214576721
# #2
# train accuracy: 0.8299999833106995	 test accuracy: 0.8555999994277954
# Epoch: #32
# #1
# train accuracy: 0.8500000238418579	 test accuracy: 0.9150000214576721
# #2
# train accuracy: 0.7699999809265137	 test accuracy: 0.8579999804496765
# Epoch: #33
# #1
# train accuracy: 0.8799999952316284	 test accuracy: 0.9156000018119812
# #2
# train accuracy: 0.7900000214576721	 test accuracy: 0.8587999939918518
# Epoch: #34
# #1
# train accuracy: 0.8700000047683716	 test accuracy: 0.9160000085830688
# #2
# train accuracy: 0.8600000143051147	 test accuracy: 0.8597999811172485
# Epoch: #36
# #1
# train accuracy: 0.8799999952316284	 test accuracy: 0.9169999957084656
# #2
# train accuracy: 0.8199999928474426	 test accuracy: 0.8622000217437744
# Epoch: #37
# #1
# train accuracy: 0.8799999952316284	 test accuracy: 0.9174000024795532
# #2
# train accuracy: 0.8199999928474426	 test accuracy: 0.8644000291824341
# Epoch: #38
# #1
# train accuracy: 0.9100000262260437	 test accuracy: 0.9174000024795532
# #2
# train accuracy: 0.8899999856948853	 test accuracy: 0.8650000095367432
# Epoch: #39
# #1
# train accuracy: 0.9300000071525574	 test accuracy: 0.9182000160217285
# #2
# train accuracy: 0.8500000238418579	 test accuracy: 0.8650000095367432
# Epoch: #41
# #1
# train accuracy: 0.9300000071525574	 test accuracy: 0.9187999963760376
# #2
# train accuracy: 0.8600000143051147	 test accuracy: 0.8677999973297119
# Epoch: #42
# #1
# train accuracy: 0.9599999785423279	 test accuracy: 0.9193999767303467
# #2
# train accuracy: 0.8700000047683716	 test accuracy: 0.8682000041007996
# Epoch: #43
# #1
# train accuracy: 0.8899999856948853	 test accuracy: 0.9190000295639038
# #2
# train accuracy: 0.8500000238418579	 test accuracy: 0.8687999844551086
# Epoch: #44
# #1
# train accuracy: 0.9200000166893005	 test accuracy: 0.920199990272522
# #2
# train accuracy: 0.8500000238418579	 test accuracy: 0.868399977684021
# Epoch: #46
# #1
# train accuracy: 0.9399999976158142	 test accuracy: 0.9197999835014343
# #2
# train accuracy: 0.8700000047683716	 test accuracy: 0.8718000054359436
# Epoch: #47
# #1
# train accuracy: 0.9200000166893005	 test accuracy: 0.9205999970436096
# #2
# train accuracy: 0.7900000214576721	 test accuracy: 0.8726000189781189
# Epoch: #48
# #1
# train accuracy: 0.949999988079071	 test accuracy: 0.9204000234603882
# #2
# train accuracy: 0.8999999761581421	 test accuracy: 0.8736000061035156
# Epoch: #49
# #1
# train accuracy: 0.9200000166893005	 test accuracy: 0.9204000234603882
# #2
# train accuracy: 0.8600000143051147	 test accuracy: 0.8737999796867371

# %%
fig,axs = plt.subplots(1,2 ,figsize=(17,10))
axs[0].plot(train_accr1)
axs[0].plot(test_accr1)
axs[1].plot(train_accr2)
axs[1].plot(test_accr2)
