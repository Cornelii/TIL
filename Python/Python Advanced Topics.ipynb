# %% [markdown]
# # Python Advanced Topics

# %% [markdown]
# ## I. Exception

# %% [markdown]
# ## II. Closure

# %% [markdown]
# * 클로져란?!
# 자신이 정의되어 있는 스코프 안에 있는 변수를 참조하는 함수를 의미한다.
#
# =는 할당의 의미
#
# 1. 현재 함수의 스코프
# 2. 현재 함수를 감싸고 있는 스코프
# 3. 전역 스코프
# 4. 내장 스코프
#
# 파이썬은 1급 객체 함수를 지원한다!
# * 1급 객체 함수란?
# (1st-class object)
# 1. 함수를 변수에 할당할 수 있다.
# 2. 다른 함수의 인수로 전달할 수 있다.
# 2. 표현식에서 사용될 수 있다.

# %%
def outer_func(a, b, *args, **kwargs):
    def inner_func(y):
        result=[]
        for val in y:
            result.append((val+a)*b)
        return result
    return inner_func

# %%
A = [0,1,2,3,4,5,6,7]

# %%
func = outer_func(5,4,*A)

# %%
print(func.__closure__[0])
# Out:
# <cell at 0x7f785865d2e8: int object at 0xa67b40>

# %%
func.__closure__[0].cell_contents
# Out:
# 5

# %% [markdown]
# a의 값

# %%
func.__closure__[1].cell_contents
# Out:
# 4

# %% [markdown]
# b의 값

# %% [markdown]
# ## III. Generator

# %% [markdown]
# ## IV. Class

# %% [markdown]
# #### i. Abstract Class

# %% [markdown]
# #### ii. Mix-in

# %% [markdown]
# #### iii. @classmethod (polymoph)

# %% [markdown]
# #### iv. @property

# %% [markdown]
# #### v. __get__, __set__, __call__

# %% [markdown]
# #### vi. other magical methods

# %% [markdown]
# ## V. Decorators
